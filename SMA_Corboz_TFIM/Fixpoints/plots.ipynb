# %%
import numpy as np
import matplotlib.pyplot as plt
    # ZZZZ = ncon([Z,Z,Z,Z],[[-1,-5],[-2,-6],[-3,-7],[-4,-8]]).reshape(16, 16)
    # ZIIZ = ncon([Z,I,I,Z],[[-1,-5],[-2,-6],[-3,-7],[-4,-8]]).reshape(16, 16)
    # ZIZI = ncon([Z,I,Z,I],[[-1,-5],[-2,-6],[-3,-7],[-4,-8]]).reshape(16, 16)
    # IZIZ = ncon([I,Z,I,Z],[[-1,-5],[-2,-6],[-3,-7],[-4,-8]]).reshape(16, 16)
    # IZZI = ncon([I,Z,Z,I],[[-1,-5],[-2,-6],[-3,-7],[-4,-8]]).reshape(16, 16)
    # ZIII = ncon([Z,I,I,I],[[-1,-5],[-2,-6],[-3,-7],[-4,-8]]).reshape(16, 16)
    # IZII = ncon([I,Z,I,I],[[-1,-5],[-2,-6],[-3,-7],[-4,-8]]).reshape(16, 16)
labels = ["ZZZZ", "ZIIZ", "ZIZI", "IZIZ","IZZI","ZIII","IZII"]
kz_obs = np.loadtxt("datas/kz_obs.txt")
kz_obs_ = np.loadtxt("datas/kz_obs_X.txt")
fig, ax = plt.subplots(figsize=(5,3), dpi = 160)
for i in [3,6]:
    
    # plt.plot(kz_obs_[:, 0], kz_obs_[:, i] ,label = labels[i], marker = 'o', markersize = 5, lw = 1)
    plt.plot(kz_obs_[:, 0], kz_obs_[:, i] ,label = labels[i-1], marker = 'o', markersize = 5, lw = 1)
# plt.ylim(0, 1)
plt.legend()
plt.show()

# %%
datas = np.load("datas/kz1.npy")
p = np.linspace(0, 2.0, 20)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'royalblue', lw= 0,marker = 'o', ms = 8, mec= 'royalblue', mfc= 'none', mew = 1.2, label = "Vacuum" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color = 'tomato', lw= 0,marker = 'o', ms = 8, mec= 'tomato', mfc= 'none', mew = 1.2, label = "Charge" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(0.5,)
plt.legend()
plt.show()

datas = np.load("datas/kz1_domain.npy")
p = np.linspace(0, 2.0, 20)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'mediumseagreen', lw= 0,marker = 'o', ms = 8, mec= 'mediumseagreen', mfc= 'none', mew = 1.2, label = "Flux" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color ='deeppink', lw= 0,marker = 'o', ms = 8, mec= 'deeppink', mfc= 'none', label = "Fermion" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(2.0,)
plt.legend()
plt.show()

# %%
datas = np.load("datas/kz25_Z2_h.npy")
p = np.linspace(0, 2.0, 20)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'royalblue', lw= 0,marker = 'o', ms = 8, mec= 'royalblue', mfc= 'none', mew = 1.2, label = "Vacuum" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color = 'tomato', lw= 0,marker = 'o', ms = 8, mec= 'tomato', mfc= 'none', mew = 1.2, label = "Charge" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(0.5,)
plt.legend()
plt.show()

datas = np.load("datas/kz25_Z2_h_domain.npy")
p = np.linspace(0, 2.0, 20)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'mediumseagreen', lw= 0,marker = 'o', ms = 8, mec= 'mediumseagreen', mfc= 'none', mew = 1.2, label = "Flux" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color ='deeppink', lw= 0,marker = 'o', ms = 8, mec= 'deeppink', mfc= 'none', label = "Fermion" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(2.0,)
plt.legend()
plt.show()

# %%
datas = np.load("datas/kz21.npy")
p = np.linspace(0, 2.0, 21)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'royalblue', lw= 0,marker = 'o', ms = 8, mec= 'royalblue', mfc= 'none', mew = 1.2, label = "Vacuum" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color = 'tomato', lw= 0,marker = 'o', ms = 8, mec= 'tomato', mfc= 'none', mew = 1.2, label = "Charge" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(0.5,)
plt.legend()
plt.show()

datas = np.load("datas/kz21_domain.npy")
p = np.linspace(0, 2.0, 21)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'mediumseagreen', lw= 0,marker = 'o', ms = 8, mec= 'mediumseagreen', mfc= 'none', mew = 1.2, label = "Flux" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color ='deeppink', lw= 0,marker = 'o', ms = 8, mec= 'deeppink', mfc= 'none', label = "Fermion" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(2.0,)
plt.legend()
plt.show()

# %%
datas = np.load("datas/kz25.npy")
p = np.linspace(0, 2.0, 21)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'royalblue', lw= 0,marker = 'o', ms = 8, mec= 'royalblue', mfc= 'none', mew = 1.2, label = "Vacuum" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color = 'tomato', lw= 0,marker = 'o', ms = 8, mec= 'tomato', mfc= 'none', mew = 1.2, label = "Charge" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(0.5,)
plt.legend()
plt.show()

datas = np.load("datas/kz25_domain.npy")
p = np.linspace(0, 2.0, 21)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'mediumseagreen', lw= 0,marker = 'o', ms = 8, mec= 'mediumseagreen', mfc= 'none', mew = 1.2, label = "Flux" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color ='deeppink', lw= 0,marker = 'o', ms = 8, mec= 'deeppink', mfc= 'none', label = "Fermion" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(2.0,)
plt.legend()
plt.show()

# %%
datas = np.load("datas/kz23.npy")
p = np.linspace(0, 2.0, 21)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'royalblue', lw= 0,marker = 'o', ms = 8, mec= 'royalblue', mfc= 'none', mew = 1.2, label = "Vacuum" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color = 'tomato', lw= 0,marker = 'o', ms = 8, mec= 'tomato', mfc= 'none', mew = 1.2, label = "Charge" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(0.5,)
plt.legend()
plt.show()

datas = np.load("datas/kz23_domain.npy")
p = np.linspace(0, 2.0, 21)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'mediumseagreen', lw= 0,marker = 'o', ms = 8, mec= 'mediumseagreen', mfc= 'none', mew = 1.2, label = "Flux" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color ='deeppink', lw= 0,marker = 'o', ms = 8, mec= 'deeppink', mfc= 'none', label = "Fermion" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(2.0,)
plt.legend()
plt.show()

# %%
datas = np.load("datas/kz25_Z2_h.npy")
p = np.linspace(0, 2.0, 21)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'royalblue', lw= 0,marker = 'o', ms = 8, mec= 'royalblue', mfc= 'none', mew = 1.2, label = "Vacuum" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color = 'tomato', lw= 0,marker = 'o', ms = 8, mec= 'tomato', mfc= 'none', mew = 1.2, label = "Charge" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(0.5,)
plt.legend()
plt.show()

datas = np.load("datas/kz25_Z2_h_domain.npy")
p = np.linspace(0, 2.0, 21)
Ceqs = -np.log(datas[2,:])
Cdiffs = -np.log(datas[3,:])
fig, ax1 = plt.subplots(figsize = (6,5),dpi=160)
for i in range(Ceqs.shape[1]):
    plt.plot(p,Ceqs[:,i], color = 'mediumseagreen', lw= 0,marker = 'o', ms = 8, mec= 'mediumseagreen', mfc= 'none', mew = 1.2, label = "Flux" if i==0 else "")
for i in range(Cdiffs.shape[1]):
    plt.plot(p,Cdiffs[:,i], color ='deeppink', lw= 0,marker = 'o', ms = 8, mec= 'deeppink', mfc= 'none', label = "Fermion" if i==0 else "")
plt.xlabel('$k_1$/$\pi$')
plt.ylabel('-log(|$\lambda$|)')
plt.ylim(2.0,)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
labels = ["IIZI", "IIIZ"]
kz_obs_ = np.loadtxt("datas/kz_obs_X2.txt")

for i in range(1,3):
    fig, ax = plt.subplots(figsize=(5,3), dpi = 160)
    # plt.plot(kz_obs_[:, 0], kz_obs_[:, i] ,label = labels[i], marker = 'o', markersize = 5, lw = 1)
    plt.plot(kz_obs_[:, 0], kz_obs_[:, i] ,label = labels[i-1], marker = 'o', markersize = 5, lw = 1)
    plt.ylim(0, 1)
    plt.legend()
    plt.show()
